# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from matplotlib.image import imread
import matplotlib.image as mpimg

#from zipfile import ZipFile
import os

# %%
import os
print(os.getcwd())
# Out:
# /kaggle/working

# %%
print(os.listdir())
# Out:
# ['__notebook__.ipynb']

# %%
path = '/kaggle/input/cat-and-dog-classification-using-cnn/dog-vs-cat'
classes = os.listdir(path)
classes
# Out:
# ['dog', 'cat']

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
cat_dir = os.path.join('/kaggle/input/cat-and-dog-classification-using-cnn/dog-vs-cat/cat')
dog_dir = os.path.join('/kaggle/input/cat-and-dog-classification-using-cnn/dog-vs-cat/dog')
cat_names = os.listdir(cat_dir)
dog_names = os.listdir(dog_dir)

pic_index = 210

cat_images = [os.path.join(cat_dir, fname)
              for fname in cat_names[pic_index-8:pic_index]]
dog_images = [os.path.join(dog_dir, fname)
              for fname in dog_names[pic_index-8:pic_index]]

for i, img_path in enumerate(cat_images + dog_images):
    sp = plt.subplot(4, 4, i+1)
    sp.axis('Off')

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
img_size=100
batch_size=1000
epochs=50
learning_rate=0.03

# %%
transform = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# %%
train_data = datasets.ImageFolder(root=path, transform=transform)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.Conv1=nn.Linear()
